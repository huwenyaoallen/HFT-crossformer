# %%
import pandas as pd

path = "part.0.parquet"
df = pd.read_parquet(path)
df
# Out:
#                      time      Volume  LastPrice  TotalBidQty  \
# 0     2024-04-30 09:30:01    243100.0       9.25    2135800.0
# 1     2024-04-30 09:30:04    301000.0       9.26    2292000.0
# 2     2024-04-30 09:30:07    354100.0       9.25    1385900.0
# 3     2024-04-30 09:30:10    394400.0       9.26    1497000.0
# 4     2024-04-30 09:30:13    444300.0       9.26    1764200.0
# ...                   ...         ...        ...          ...
# 4875  2024-04-30 14:56:46  30806117.0       9.18    1803600.0
# 4876  2024-04-30 14:56:49  30810217.0       9.19    1801900.0
# 4877  2024-04-30 14:56:52  30811517.0       9.19    1801400.0
# 4878  2024-04-30 14:56:55  30813017.0       9.18    1766000.0
# 4879  2024-04-30 14:56:58  30813717.0       9.18    1757900.0
#
#       WeightedAvgBidPx  TotalOfferQty  WeightedAvgOfferPx  AskPrice1  \
# 0                9.144      2605600.0               9.684       9.25
# 1                9.149      2726100.0               9.678       9.26
# 2                9.100      2932300.0               9.667       9.26
# 3                9.105      3112400.0               9.659       9.27
# 4                9.112      3376200.0               9.645       9.26
# ...                ...            ...                 ...        ...
# 4875             9.092     11395458.0               9.535       9.19
# 4876             9.092     11399558.0               9.535       9.19
# 4877             9.092     11382058.0               9.535       9.19
# 4878             9.091     11377358.0               9.535       9.19
# 4879             9.091     11407158.0               9.534       9.19
#
#       AskVolume1  BidPrice1  BidVolume1  AskPrice2  AskVolume2  BidPrice2  \
# 0         6500.0       9.24     61100.0       9.26     23300.0       9.23
# 1        16800.0       9.25     63800.0       9.27     51600.0       9.24
# 2        12400.0       9.25     85300.0       9.27     54800.0       9.24
# 3        56800.0       9.26      1500.0       9.28    130900.0       9.25
# 4         4500.0       9.25     44600.0       9.27     52000.0       9.24
# ...          ...        ...         ...        ...         ...        ...
# 4875     30000.0       9.18    172800.0       9.20    222300.0       9.17
# 4876     35100.0       9.18    171900.0       9.20    221800.0       9.17
# 4877     38900.0       9.18    171700.0       9.20    221800.0       9.17
# 4878     37500.0       9.18    172100.0       9.20    221800.0       9.17
# 4879     77300.0       9.18    171500.0       9.20    211800.0       9.17
#
#       BidVolume2  BuyPrice  SellPrice  LogReturn
# 0         5100.0      9.26       9.21  -0.005414
# 1        43300.0      9.25       9.21  -0.004334
# 2        55200.0      9.26       9.21  -0.005414
# 3        76900.0      9.26       9.21  -0.005414
# 4        55000.0      9.26       9.21  -0.005414
# ...          ...       ...        ...        ...
# 4875    210800.0      9.19        NaN        NaN
# 4876    213100.0      9.19        NaN        NaN
# 4877    212800.0      9.18        NaN        NaN
# 4878    212800.0      9.18        NaN        NaN
# 4879    212800.0       NaN        NaN        NaN
#
# [4880 rows x 18 columns]

# %%
df=pd.read_csv("Crossformer/datasets/hf.csv")
df[1:3]
# Out:
#                   time    Volume  LastPrice  TotalBidQty  WeightedAvgBidPx  \
# 1  2024-04-30 09:30:04 -2.952853   1.963909     0.131896          3.536634
# 2  2024-04-30 09:30:07 -2.942334   1.562792    -3.308111          0.594524
#
#    TotalOfferQty  WeightedAvgOfferPx  AskPrice1  AskVolume1  BidPrice1  \
# 1      -4.343200            5.265693   1.798695   -1.045933   1.803815
# 2      -4.227462            4.816994   1.798695   -1.117476   1.803815
#
#    BidVolume1  AskPrice2  AskVolume2  BidPrice2  BidVolume2  LogReturn
# 1   -0.187644   1.798277   -1.177115   1.804334   -1.289863  -0.004334
# 2    0.106545   1.798277   -1.133260   1.804334   -1.135506  -0.005414

# %%
df[2:3]
# Out:
#                   time    Volume  LastPrice  TotalBidQty  WeightedAvgBidPx  \
# 2  2024-04-30 09:30:07 -2.942334   1.562792    -3.308111          0.594524
#
#    TotalOfferQty  WeightedAvgOfferPx  AskPrice1  AskVolume1  BidPrice1  \
# 2      -4.227462            4.816994   1.798695   -1.117476   1.803815
#
#    BidVolume1  AskPrice2  AskVolume2  BidPrice2  BidVolume2  LogReturn
# 2    0.106545   1.798277    -1.13326   1.804334   -1.135506  -0.005414

# %%
df.head(1)
# Out:
#                   time    Volume  LastPrice  TotalBidQty  WeightedAvgBidPx  \
# 0  2024-04-30 09:30:01  243100.0       9.25    2135800.0             9.144
#
#    TotalOfferQty  WeightedAvgOfferPx  AskPrice1  AskVolume1  BidPrice1  \
# 0      2605600.0               9.684       9.25      6500.0       9.24
#
#    BidVolume1  AskPrice2  AskVolume2  BidPrice2  BidVolume2  BuyPrice  \
# 0     61100.0       9.26     23300.0       9.23      5100.0      9.26
#
#    SellPrice  LogReturn
# 0       9.21  -0.005414

# %%
df = df.drop(['BuyPrice', 'SellPrice'], axis=1)

# %%
df
# Out:
#                      time      Volume  LastPrice  TotalBidQty  \
# 0     2024-04-30 09:30:01    243100.0       9.25    2135800.0
# 1     2024-04-30 09:30:04    301000.0       9.26    2292000.0
# 2     2024-04-30 09:30:07    354100.0       9.25    1385900.0
# 3     2024-04-30 09:30:10    394400.0       9.26    1497000.0
# 4     2024-04-30 09:30:13    444300.0       9.26    1764200.0
# ...                   ...         ...        ...          ...
# 4875  2024-04-30 14:56:46  30806117.0       9.18    1803600.0
# 4876  2024-04-30 14:56:49  30810217.0       9.19    1801900.0
# 4877  2024-04-30 14:56:52  30811517.0       9.19    1801400.0
# 4878  2024-04-30 14:56:55  30813017.0       9.18    1766000.0
# 4879  2024-04-30 14:56:58  30813717.0       9.18    1757900.0
#
#       WeightedAvgBidPx  TotalOfferQty  WeightedAvgOfferPx  AskPrice1  \
# 0                9.144      2605600.0               9.684       9.25
# 1                9.149      2726100.0               9.678       9.26
# 2                9.100      2932300.0               9.667       9.26
# 3                9.105      3112400.0               9.659       9.27
# 4                9.112      3376200.0               9.645       9.26
# ...                ...            ...                 ...        ...
# 4875             9.092     11395458.0               9.535       9.19
# 4876             9.092     11399558.0               9.535       9.19
# 4877             9.092     11382058.0               9.535       9.19
# 4878             9.091     11377358.0               9.535       9.19
# 4879             9.091     11407158.0               9.534       9.19
#
#       AskVolume1  BidPrice1  BidVolume1  AskPrice2  AskVolume2  BidPrice2  \
# 0         6500.0       9.24     61100.0       9.26     23300.0       9.23
# 1        16800.0       9.25     63800.0       9.27     51600.0       9.24
# 2        12400.0       9.25     85300.0       9.27     54800.0       9.24
# 3        56800.0       9.26      1500.0       9.28    130900.0       9.25
# 4         4500.0       9.25     44600.0       9.27     52000.0       9.24
# ...          ...        ...         ...        ...         ...        ...
# 4875     30000.0       9.18    172800.0       9.20    222300.0       9.17
# 4876     35100.0       9.18    171900.0       9.20    221800.0       9.17
# 4877     38900.0       9.18    171700.0       9.20    221800.0       9.17
# 4878     37500.0       9.18    172100.0       9.20    221800.0       9.17
# 4879     77300.0       9.18    171500.0       9.20    211800.0       9.17
#
#       BidVolume2  LogReturn
# 0         5100.0  -0.005414
# 1        43300.0  -0.004334
# 2        55200.0  -0.005414
# 3        76900.0  -0.005414
# 4        55000.0  -0.005414
# ...          ...        ...
# 4875    210800.0        NaN
# 4876    213100.0        NaN
# 4877    212800.0        NaN
# 4878    212800.0        NaN
# 4879    212800.0        NaN
#
# [4880 rows x 16 columns]

# %%
null_count = df['LogReturn'].isnull().sum()
print(null_count)
# Out:
# 1800

# %%
null_rows = df[df['LogReturn'].isnull()].index
print("The null values in 'Logreturn' column are located in the following rows:")
for row in null_rows:
    print(row)
# Out:
# The null values in 'Logreturn' column are located in the following rows:
# 3080
# 3081
# 3082
# 3083
# 3084
# 3085
# 3086
# 3087
# 3088
# 3089
# 3090
# 3091
# 3092
# 3093
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# 3131
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# 3140
# 3141
# 3142
# 3143
# 3144
# 3145
# 3146
# 3147
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# 3159
# 3160
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394
# 3395
# 3396
# 3397
# 3398
# 3399
# 3400
# 3401
# 3402
# 3403
# 3404
# 3405
# 3406
# 3407
# 3408
# 3409
# 3410
# 3411
# 3412
# 3413
# 3414
# 3415
# 3416
# 3417
# 3418
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# 3426
# 3427
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# 3435
# 3436
# 3437
# 3438
# 3439
# 3440
# 3441
# 3442
# 3443
# 3444
# 3445
# 3446
# 3447
# 3448
# 3449
# 3450
# 3451
# 3452
# 3453
# 3454
# 3455
# 3456
# 3457
# 3458
# 3459
# 3460
# 3461
# 3462
# 3463
# 3464
# 3465
# 3466
# 3467
# 3468
# 3469
# 3470
# 3471
# 3472
# 3473
# 3474
# 3475
# 3476
# 3477
# 3478
# 3479
# 3480
# 3481
# 3482
# 3483
# 3484
# 3485
# 3486
# 3487
# 3488
# 3489
# 3490
# 3491
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# 3557
# 3558
# 3559
# 3560
# 3561
# 3562
# 3563
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# 3572
# 3573
# 3574
# 3575
# 3576
# 3577
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# 3589
# 3590
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# 3648
# 3649
# 3650
# 3651
# 3652
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# 3675
# 3676
# 3677
# 3678
# 3679
# 3680
# 3681
# 3682
# 3683
# 3684
# 3685
# 3686
# 3687
# 3688
# 3689
# 3690
# 3691
# 3692
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# 3699
# 3700
# 3701
# 3702
# 3703
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# 3711
# 3712
# 3713
# 3714
# 3715
# 3716
# 3717
# 3718
# 3719
# 3720
# 3721
# 3722
# 3723
# 3724
# 3725
# 3726
# 3727
# 3728
# 3729
# 3730
# 3731
# 3732
# 3733
# 3734
# 3735
# 3736
# 3737
# 3738
# 3739
# 3740
# 3741
# 3742
# 3743
# 3744
# 3745
# 3746
# 3747
# 3748
# 3749
# 3750
# 3751
# 3752
# 3753
# 3754
# 3755
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# 3764
# 3765
# 3766
# 3767
# 3768
# 3769
# 3770
# 3771
# 3772
# 3773
# 3774
# 3775
# 3776
# 3777
# 3778
# 3779
# 3780
# 3781
# 3782
# 3783
# 3784
# 3785
# 3786
# 3787
# 3788
# 3789
# 3790
# 3791
# 3792
# 3793
# 3794
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3801
# 3802
# 3803
# 3804
# 3805
# 3806
# 3807
# 3808
# 3809
# 3810
# 3811
# 3812
# 3813
# 3814
# 3815
# 3816
# 3817
# 3818
# 3819
# 3820
# 3821
# 3822
# 3823
# 3824
# 3825
# 3826
# 3827
# 3828
# 3829
# 3830
# 3831
# 3832
# 3833
# 3834
# 3835
# 3836
# 3837
# 3838
# 3839
# 3840
# 3841
# 3842
# 3843
# 3844
# 3845
# 3846
# 3847
# 3848
# 3849
# 3850
# 3851
# 3852
# 3853
# 3854
# 3855
# 3856
# 3857
# 3858
# 3859
# 3860
# 3861
# 3862
# 3863
# 3864
# 3865
# 3866
# 3867
# 3868
# 3869
# 3870
# 3871
# 3872
# 3873
# 3874
# 3875
# 3876
# 3877
# 3878
# 3879
# 3880
# 3881
# 3882
# 3883
# 3884
# 3885
# 3886
# 3887
# 3888
# 3889
# 3890
# 3891
# 3892
# 3893
# 3894
# 3895
# 3896
# 3897
# 3898
# 3899
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# 3908
# 3909
# 3910
# 3911
# 3912
# 3913
# 3914
# 3915
# 3916
# 3917
# 3918
# 3919
# 3920
# 3921
# 3922
# 3923
# 3924
# 3925
# 3926
# 3927
# 3928
# 3929
# 3930
# 3931
# 3932
# 3933
# 3934
# 3935
# 3936
# 3937
# 3938
# 3939
# 3940
# 3941
# 3942
# 3943
# 3944
# 3945
# 3946
# 3947
# 3948
# 3949
# 3950
# 3951
# 3952
# 3953
# 3954
# 3955
# 3956
# 3957
# 3958
# 3959
# 3960
# 3961
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# 3976
# 3977
# 3978
# 3979
# 3980
# 3981
# 3982
# 3983
# 3984
# 3985
# 3986
# 3987
# 3988
# 3989
# 3990
# 3991
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# 3998
# 3999
# 4000
# 4001
# 4002
# 4003
# 4004
# 4005
# 4006
# 4007
# 4008
# 4009
# 4010
# 4011
# 4012
# 4013
# 4014
# 4015
# 4016
# 4017
# 4018
# 4019
# 4020
# 4021
# 4022
# 4023
# 4024
# 4025
# 4026
# 4027
# 4028
# 4029
# 4030
# 4031
# 4032
# 4033
# 4034
# 4035
# 4036
# 4037
# 4038
# 4039
# 4040
# 4041
# 4042
# 4043
# 4044
# 4045
# 4046
# 4047
# 4048
# 4049
# 4050
# 4051
# 4052
# 4053
# 4054
# 4055
# 4056
# 4057
# 4058
# 4059
# 4060
# 4061
# 4062
# 4063
# 4064
# 4065
# 4066
# 4067
# 4068
# 4069
# 4070
# 4071
# 4072
# 4073
# 4074
# 4075
# 4076
# 4077
# 4078
# 4079
# 4080
# 4081
# 4082
# 4083
# 4084
# 4085
# 4086
# 4087
# 4088
# 4089
# 4090
# 4091
# 4092
# 4093
# 4094
# 4095
# 4096
# 4097
# 4098
# 4099
# 4100
# 4101
# 4102
# 4103
# 4104
# 4105
# 4106
# 4107
# 4108
# 4109
# 4110
# 4111
# 4112
# 4113
# 4114
# 4115
# 4116
# 4117
# 4118
# 4119
# 4120
# 4121
# 4122
# 4123
# 4124
# 4125
# 4126
# 4127
# 4128
# 4129
# 4130
# 4131
# 4132
# 4133
# 4134
# 4135
# 4136
# 4137
# 4138
# 4139
# 4140
# 4141
# 4142
# 4143
# 4144
# 4145
# 4146
# 4147
# 4148
# 4149
# 4150
# 4151
# 4152
# 4153
# 4154
# 4155
# 4156
# 4157
# 4158
# 4159
# 4160
# 4161
# 4162
# 4163
# 4164
# 4165
# 4166
# 4167
# 4168
# 4169
# 4170
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879

# %%
df = df.dropna(subset=['LogReturn'])
df
# Out:
#                      time      Volume  LastPrice  TotalBidQty  \
# 0     2024-04-30 09:30:01    243100.0       9.25    2135800.0
# 1     2024-04-30 09:30:04    301000.0       9.26    2292000.0
# 2     2024-04-30 09:30:07    354100.0       9.25    1385900.0
# 3     2024-04-30 09:30:10    394400.0       9.26    1497000.0
# 4     2024-04-30 09:30:13    444300.0       9.26    1764200.0
# ...                   ...         ...        ...          ...
# 3075  2024-04-30 13:25:34  22105590.0       9.20    2592400.0
# 3076  2024-04-30 13:25:37  22107890.0       9.20    2583400.0
# 3077  2024-04-30 13:25:40  22108090.0       9.19    2589700.0
# 3078  2024-04-30 13:25:43  22108290.0       9.19    2592100.0
# 3079  2024-04-30 13:25:46  22111290.0       9.20    2593200.0
#
#       WeightedAvgBidPx  TotalOfferQty  WeightedAvgOfferPx  AskPrice1  \
# 0                9.144      2605600.0               9.684       9.25
# 1                9.149      2726100.0               9.678       9.26
# 2                9.100      2932300.0               9.667       9.26
# 3                9.105      3112400.0               9.659       9.27
# 4                9.112      3376200.0               9.645       9.26
# ...                ...            ...                 ...        ...
# 3075             9.082     11850158.0               9.531       9.21
# 3076             9.082     11851258.0               9.531       9.20
# 3077             9.082     11836558.0               9.531       9.20
# 3078             9.082     11836558.0               9.531       9.20
# 3079             9.082     11836558.0               9.531       9.20
#
#       AskVolume1  BidPrice1  BidVolume1  AskPrice2  AskVolume2  BidPrice2  \
# 0         6500.0       9.24     61100.0       9.26     23300.0       9.23
# 1        16800.0       9.25     63800.0       9.27     51600.0       9.24
# 2        12400.0       9.25     85300.0       9.27     54800.0       9.24
# 3        56800.0       9.26      1500.0       9.28    130900.0       9.25
# 4         4500.0       9.25     44600.0       9.27     52000.0       9.24
# ...          ...        ...         ...        ...         ...        ...
# 3075    287500.0       9.20       900.0       9.22    282100.0       9.19
# 3076      1800.0       9.19    120200.0       9.21    287600.0       9.18
# 3077      3800.0       9.19    125700.0       9.21    273100.0       9.18
# 3078      3800.0       9.19    126200.0       9.21    273100.0       9.18
# 3079      3800.0       9.19    127300.0       9.21    273100.0       9.18
#
#       BidVolume2  LogReturn
# 0         5100.0  -0.005414
# 1        43300.0  -0.004334
# 2        55200.0  -0.005414
# 3        76900.0  -0.005414
# 4        55000.0  -0.005414
# ...          ...        ...
# 3075    128900.0  -0.002176
# 3076     70300.0   0.000000
# 3077     70600.0   0.000000
# 3078     72500.0  -0.002176
# 3079     72500.0  -0.001089
#
# [3080 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# time                  0
# Volume                0
# LastPrice             0
# TotalBidQty           0
# WeightedAvgBidPx      0
# TotalOfferQty         0
# WeightedAvgOfferPx    0
# AskPrice1             0
# AskVolume1            0
# BidPrice1             0
# BidVolume1            0
# AskPrice2             0
# AskVolume2            0
# BidPrice2             0
# BidVolume2            0
# LogReturn             0
# dtype: int64

# %%
columns = ['Volume','LastPrice','TotalBidQty','WeightedAvgBidPx','TotalOfferQty','WeightedAvgOfferPx','AskPrice1','AskVolume1','BidPrice1','BidVolume1','AskPrice2','AskVolume2','BidPrice2','BidVolume2']

for col in columns:
    col_mean = df[col].mean()  
    col_std = df[col].std()  
    df[col] = (df[col] - col_mean) / col_std  

print(df)
# Out:
#                      time    Volume  LastPrice  TotalBidQty  WeightedAvgBidPx  \
# 0     2024-04-30 09:30:01 -2.964323   1.562792    -0.461117          3.236419
# 1     2024-04-30 09:30:04 -2.952853   1.963909     0.131896          3.536634
# 2     2024-04-30 09:30:07 -2.942334   1.562792    -3.308111          0.594524
# 3     2024-04-30 09:30:10 -2.934350   1.963909    -2.886320          0.894739
# 4     2024-04-30 09:30:13 -2.924464   1.963909    -1.871896          1.315041
# ...                   ...       ...        ...          ...               ...
# 3075  2024-04-30 13:25:34  1.366783  -0.442791     1.272365         -0.486251
# 3076  2024-04-30 13:25:37  1.367239  -0.442791     1.238196         -0.486251
# 3077  2024-04-30 13:25:40  1.367278  -0.843908     1.262114         -0.486251
# 3078  2024-04-30 13:25:43  1.367318  -0.843908     1.271226         -0.486251
# 3079  2024-04-30 13:25:46  1.367912  -0.442791     1.275402         -0.486251
#
#       TotalOfferQty  WeightedAvgOfferPx  AskPrice1  AskVolume1  BidPrice1  \
# 0         -4.410835            5.510438   1.387015   -1.213410   1.392278
# 1         -4.343200            5.265693   1.798695   -1.045933   1.803815
# 2         -4.227462            4.816994   1.798695   -1.117476   1.803815
# 3         -4.126374            4.490668   2.210375   -0.395535   2.215352
# 4         -3.978306            3.919597   1.798695   -1.245930   1.803815
# ...             ...                 ...        ...         ...        ...
# 3075       0.778027           -0.730552  -0.259706    3.355632  -0.253870
# 3076       0.778644           -0.730552  -0.671386   -1.289832  -0.665407
# 3077       0.770393           -0.730552  -0.671386   -1.257312  -0.665407
# 3078       0.770393           -0.730552  -0.671386   -1.257312  -0.665407
# 3079       0.770393           -0.730552  -0.671386   -1.257312  -0.665407
#
#       BidVolume1  AskPrice2  AskVolume2  BidPrice2  BidVolume2  LogReturn
# 0      -0.224588   1.386662   -1.564952   1.392709   -1.785361  -0.005414
# 1      -0.187644   1.798277   -1.177115   1.804334   -1.289863  -0.004334
# 2       0.106545   1.798277   -1.133260   1.804334   -1.135506  -0.005414
# 3      -1.040107   2.209893   -0.090349   2.215959   -0.854032  -0.005414
# 3077    0.659346  -0.671414    1.858429  -0.665416   -0.935750   0.000000
# 3078    0.666188  -0.671414    1.858429  -0.665416   -0.911105  -0.002176
# 3079    0.681239  -0.671414    1.858429  -0.665416   -0.911105  -0.001089
#
# [3080 rows x 16 columns]

# %%
import torch

# 创建两个示例张量
a = torch.tensor([[1, 2], [3, 4]])
b = torch.tensor([[5, 6], [7, 8]])

# 创建包含这两个张量的列表
seg_to_merge = [a, b]

# 使用torch.cat函数沿着最后一个维度拼接这两个张量
x = torch.cat(seg_to_merge, -1)

# 输出拼接后的张量
print("拼接后的张量：")
print(x)
a.shape
# Out:
# 拼接后的张量：
# tensor([[1, 2, 5, 6],
#         [3, 4, 7, 8]])
# torch.Size([2, 2])

# %%
import torch
from einops import rearrange

# 示例参数
b = 2  # 批次大小
out_d = 3  # 输出维度
seg_num = 4  # 段落数量
seg_len = 5  # 每个段的长度

# 随机生成示例张量 final_predict
final_predict = torch.randn(b, out_d * seg_num, seg_len)
print("原始 final_predict 张量：")
print(final_predict)

# 使用 rearrange 函数重新排列 final_predict 张量
rearranged_predict = rearrange(final_predict, 'b (out_d seg_num) seg_len -> b (seg_num seg_len) out_d', out_d=out_d)
print("\n重新排列后的 final_predict 张量：")
print(rearranged_predict)
# Out:
# 原始 final_predict 张量：
# tensor([[[ 0.6262, -0.0233,  0.6629,  0.1374,  0.1178],
#          [-1.3636,  0.2824,  0.7955,  1.2888,  0.2963],
#          [-1.1468,  1.5699,  0.0420,  0.4930,  0.7696],
#          [-0.7035,  0.2744, -0.4257,  0.0324, -0.4872],
#          [-1.0261,  0.1229, -0.1106,  0.5236,  0.5603],
#          [ 0.6450,  0.8604,  0.0988,  0.5084,  0.2874],
#          [ 0.8394,  0.4115, -1.1119,  0.8520,  1.5775],
#          [ 1.1657,  0.2791, -1.1700,  0.2138, -0.6792],
#          [ 0.0425, -0.9457, -0.0536, -1.4396, -1.1177],
#          [ 1.4354, -2.0857,  0.7053, -0.4977, -0.3397],
#          [ 0.7459,  0.2720, -1.0283,  0.1502,  0.5427],
#          [ 1.2964, -0.3306, -2.5910,  0.2663, -1.0804]],
#
#         [[-0.8302, -0.3799, -0.1024,  0.7141, -1.2451],
#          [ 0.8004, -1.1981, -0.3736,  1.4854,  1.1336],
#          [-0.2066,  0.6627,  1.7073,  0.4063, -2.5493],
#          [ 1.7730,  2.2595, -1.1409,  1.1361,  0.1768],
#          [ 1.4051, -0.3814,  0.1445, -1.7346,  0.5159],
#          [-0.1619,  0.4194,  0.7583, -1.4154,  0.8129],
#          [-0.1144,  1.6748,  1.0284, -0.6264, -0.4459],
#          [-0.8904,  1.2227, -1.7565, -0.1210,  1.6113],
#          [ 0.3553, -0.3747, -0.1922, -0.2434,  0.5119],
#          [-0.4053,  0.2769,  0.0942, -3.0871, -0.7098],
#          [ 0.3053,  1.2805, -0.4767, -0.6958, -0.2898],
#          [-0.4791, -0.2708,  0.2496, -1.0369,  1.0616]]])
#
# 重新排列后的 final_predict 张量：
# tensor([[[ 0.6262, -1.0261,  0.0425],
#          [-0.0233,  0.1229, -0.9457],
#          [ 0.6629, -0.1106, -0.0536],
#          [ 0.1374,  0.5236, -1.4396],
#          [ 0.1178,  0.5603, -1.1177],
#          [-1.3636,  0.6450,  1.4354],
#          [ 0.2824,  0.8604, -2.0857],
#          [ 0.7955,  0.0988,  0.7053],
#          [ 1.2888,  0.5084, -0.4977],
#          [ 0.2963,  0.2874, -0.3397],
#          [-1.1468,  0.8394,  0.7459],
#          [ 1.5699,  0.4115,  0.2720],
#          [ 0.0420, -1.1119, -1.0283],
#          [ 0.4930,  0.8520,  0.1502],
#          [ 0.7696,  1.5775,  0.5427],
#          [-0.7035,  1.1657,  1.2964],
#          [ 0.2744,  0.2791, -0.3306],
#          [-0.4257, -1.1700, -2.5910],
#          [ 0.0324,  0.2138,  0.2663],
#          [-0.4872, -0.6792, -1.0804]],
#
#         [[-0.8302,  1.4051,  0.3553],
#          [-0.3799, -0.3814, -0.3747],
#          [-0.1024,  0.1445, -0.1922],
#          [ 0.7141, -1.7346, -0.2434],
#          [-1.2451,  0.5159,  0.5119],
#          [ 0.8004, -0.1619, -0.4053],
#          [-1.1981,  0.4194,  0.2769],
#          [-0.3736,  0.7583,  0.0942],
#          [ 1.4854, -1.4154, -3.0871],
#          [ 1.1336,  0.8129, -0.7098],
#          [-0.2066, -0.1144,  0.3053],
#          [ 0.6627,  1.6748,  1.2805],
#          [ 1.7073,  1.0284, -0.4767],
#          [ 0.4063, -0.6264, -0.6958],
#          [-2.5493, -0.4459, -0.2898],
#          [ 1.7730, -0.8904, -0.4791],
#          [ 2.2595,  1.2227, -0.2708],
#          [-1.1409, -1.7565,  0.2496],
#          [ 1.1361, -0.1210, -1.0369],
#          [ 0.1768,  1.6113,  1.0616]]])

# %%
self.decode_layers = nn.ModuleList()
self.decode_layers.append(MaxPoolingLayer())

# %%
class Decoder(nn.Module):
    '''
    The decoder of Crossformer, making the final prediction by adding up predictions at each scale
    '''
    def __init__(self, seg_len, d_layers, d_model, n_heads, d_ff, dropout,\
                router=False, out_seg_num = 10, factor=10):
        super(Decoder, self).__init__()

        self.router = router
        self.decode_layers = nn.ModuleList()
        for i in range(d_layers):
            self.decode_layers.append(MaxPoolingLayer())
    #接受输出为x
    def forward(self, x, cross):
        #提取时间步长维度
        final_predict = None
        i = 0
        #获取时间步长
        ts_d = x.shape[1]
        for layer in self.decode_layers:
            cross_enc = cross[i]
            layer_predict = layer(cross_enc)
            #第一次迭代，预测为该层预测，否则进行累加
            if final_predict is None:
                final_predict = layer_predict
            else:
                final_predict = final_predict + layer_predict
            i += 1
        
        final_predict = rearrange(final_predict, 'b (out_d seg_num) seg_len -> b (seg_num seg_len) out_d', out_d = ts_d)
        #x输入:b ts_d seg_num d_model
        return final_predict

# %%
class Decoder(nn.Module):
    '''
    The decoder of Crossformer, making the final prediction by adding up predictions at each scale
    '''
    def __init__(self, seg_len, d_layers, d_model, n_heads, d_ff, dropout,\
                router=False, out_seg_num = 10, factor=10):
        super(Decoder, self).__init__()

        self.router = router
        self.decode_layers = nn.ModuleList()
        for i in range(d_layers):
            self.decode_layers.append(DecoderLayer(seg_len, d_model, n_heads, d_ff, dropout, \
                                        out_seg_num, factor))
    #接受输出为x
    def forward(self, x, cross):
        #提取时间步长维度
        final_predict = None
        i = 0
        #获取时间步长
        ts_d = x.shape[1]
        for layer in self.decode_layers:
            cross_enc = cross[i]
            x, layer_predict = layer(x,  cross_enc)
            #第一次迭代，预测为该层预测，否则进行累加
            if final_predict is None:
                final_predict = layer_predict
            else:
                final_predict = final_predict + layer_predict
            i += 1
        
        final_predict = rearrange(final_predict, 'b (out_d seg_num) seg_len -> b (seg_num seg_len) out_d', out_d = ts_d)
        #x输入:b ts_d seg_num d_model
        return final_predict

# %%
import torch


tensor = torch.randn(2,3,4)


output= torch.mean(tensor, dim=1, keepdim=True)
print(tensor)
print(output)
# 输出张量的形状为 (b, 1, in_seg_num, d_model)
print(output.shape)
# Out:
# tensor([[[ 3.0416, -1.2412,  0.3960,  0.7128],
#          [ 1.5999, -0.6449,  0.7850,  0.2560],
#          [ 1.5819, -1.0707,  0.0276, -0.2570]],
#
#         [[-0.2548,  1.2035, -0.0185, -0.4321],
#          [ 1.2907, -0.8717,  0.8609,  1.1416],
#          [ 2.6144,  1.0878, -1.9365, -2.1830]]])
# tensor([[[ 2.0745, -0.9856,  0.4029,  0.2373]],
#
#         [[ 1.2168,  0.4732, -0.3647, -0.4912]]])
# torch.Size([2, 1, 4])

# %%
class MaxPoolingLayer(nn.Module):
    def __init__(self,seg_len, d_model):
        super(MaxPoolingLayer, self).__init__()
        self.MLP1 = nn.Sequential(nn.Linear(d_model, d_model),
                                nn.GELU(),
                                nn.Linear(d_model, d_model))
        #映射到段的长度
        self.linear_pred = nn.Linear(d_model, seg_len)

    def forward(self, x):
        # 对 ts_d 维度进行最大池化操作，并保持维度
        pooled_output, _ = torch.max(x, dim=2, keepdim=True)
        # 对 seg_num 维度进行平均池化操作
        pooled_output = torch.mean(pooled_output, dim=1,keepdim=True)
        pooled_output = self.MLP1(pooled_output)
        layer_predict = self.linear_pred(pooled_output)


        layer_predict = rearrange(pooled_output, 'b out_d seg_num seg_len -> b (out_d seg_num) seg_len')
        #print(layer_predict.shape)

        return layer_predict

class Decoder(nn.Module):
    '''
    The decoder of Crossformer, making the final prediction by adding up predictions at each scale
    '''
    def __init__(self, seg_len, d_layers, d_model, n_heads, d_ff, dropout,\
                router=False, out_seg_num = 10, factor=10):
        super(Decoder, self).__init__()

        self.router = router
        self.decode_layers = nn.ModuleList()
        for i in range(d_layers):
            self.decode_layers.append(MaxPoolingLayer(seg_len, d_model))
    #接受输出为x
    def forward(self, x, cross):
        #提取时间步长维度
        final_predict = None
        i = 0
        #获取时间步长
        ts_d = x.shape[1]
        for layer in self.decode_layers:
            cross_enc = cross[i]
            layer_predict = layer(cross_enc)
            #第一次迭代，预测为该层预测，否则进行累加
            if final_predict is None:
                final_predict = layer_predict
            else:
                final_predict = final_predict + layer_predict
            i += 1
        
        final_predict = rearrange(final_predict, 'b (out_d seg_num) seg_len -> b (seg_num seg_len) out_d', out_d = 1)
        #print(final_predict.shape)
        #x输入:b ts_d seg_num d_model
        return final_predict
